# %%
# !head embeddings/en_wn_full/s2sg_c300_pen8_c1_F/coverage_and_eval
# Out:
# Traceback (most recent call last):
#   File "word-embeddings-benchmarks/scripts/evaluate_on_all.py", line 21, in <module>
#     from web.embeddings import fetch_GloVe, load_embedding
#   File "/content/cpae-bias/cpae/word-embeddings-benchmarks/web/embeddings.py", line 7, in <module>
#     from .datasets.utils import _get_dataset_dir, _fetch_file
#   File "/content/cpae-bias/cpae/word-embeddings-benchmarks/web/datasets/utils.py", line 22, in <module>
#     import pandas as pd
# ImportError: No module named pandas

# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/ed-w-lee/cpae-bias.git
# Out:
# Cloning into 'cpae-bias'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 124 (delta 13), reused 121 (delta 10), pack-reused 0
# Receiving objects: 100% (124/124), 8.18 MiB | 15.42 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# %%bash
#
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT -q
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX 2>&1 >/dev/null
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# !conda create --name cpae python=2 --yes -q
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/cpae
#
#   added / updated specs:
#     - python=2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py27_0         156 KB
#     python-2.7.18              |       h15b4118_1        12.7 MB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     sqlite-3.33.0              |       h62c20be_0         2.0 MB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     libedit-3.1.20191231       |       h14c3975_1         121 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
# ...

# %%
# %%bash
#
# source activate cpae
# conda install pygpu theano -c mila-udem --yes
# pip install git+git://github.com/mila-udem/blocks.git \
#   -r https://raw.githubusercontent.com/mila-udem/blocks/master/requirements.txt
# pip install git+git://github.com/mila-udem/fuel.git@stable
# conda install nltk -q --yes
# pip install wordnik
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/cpae
#
#   added / updated specs:
#     - pygpu
#     - theano
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     markupsafe-1.1.1           |   py27h7b6447c_0          29 KB
#     binutils_impl_linux-64-2.33.1|       he6710b0_7         8.6 MB
#     mkl_random-1.1.0           |   py27hd6b4f25_0         332 KB
#     gcc_linux-64-7.3.0         |      h553295d_15          25 KB
#     libgfortran-ng-7.3.0       |       hdf63c60_0         1.3 MB
#     blas-1.0                   |              mkl           6 KB
#     gxx_impl_linux-64-7.3.0    |       hdf63c60_1        18.7 MB
#     gxx_linux-64-7.3.0         |      h553295d_15          25 KB
#     mkl-service-2.3.0          |   py27he904b0f_0         205 KB
#     mkl-2020.2                 |              256       213.9 MB
# ...

# %%
# %cd /content/cpae-bias/cpae
# %ls
# Out:
# /content/cpae-bias/cpae
# analyze_one_shot.sh*           LICENSE
# bin/                           notebooks/
# build_full_dict.sh*            preparation_dict2vec/
# build_pretrained_archive.sh*   preparation_retrofitting/
# build_pretrained_w2v_defs.sh*  README.md
# build_split_dict.sh*           requirements.txt
# data/                          run.sh*
# dictlearn/                     word-embeddings-benchmarks/
# evaluate_embeddings.sh*

# %%
import os
os.environ['PATH'] = '/usr/local/envs/cpae/bin:' + os.environ['PATH']
# %env PATH
# Out:
# '/usr/local/envs/cpae/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin'

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# %%bash
# python --version
# ./build_full_dict.sh
# ./build_split_dict.sh
# Out:
# Remove stopwords, multi-word expressions and recover case
# deleted 77 stop words
# deleted 64188 multi word expressions
# [u'L', u'l'] l
# [u'U', u'u'] u
# [u'N', u'n'] n
# [u'Moon', u'moon'] moon
# [u'sun', u'Sun'] sun
# [u'G', u'g'] g
# [u'W', u'w'] w
# [u'utopian', u'Utopian'] utopian
# [u'B', u'b'] b
# [u'KB', u'kB'] kb
# [u'KB', u'kB'] kb
# [u'Q', u'q'] q
# [u'R', u'r'] r
# [u'K', u'k'] k
# [u'J', u'j'] j
# [u'E', u'e'] e
# [u'V', u'v'] v
# [u'F', u'f'] f
# [u'ddI', u'DDI'] ddi
# [u'ddC', u'DDC'] ddc
# [u'Earth', u'earth'] earth
# [u'Earth', u'earth'] earth
# [u'H', u'h'] h
# [u'Z', u'z'] z
# [u'X', u'x'] x
# [u'P', u'p'] p
# [u'Doomsday', u'doomsday'] doomsday
# [u'baroque', u'Baroque'] baroque
# [u'C', u'c'] c
# Merge definitions
# a<sep>b
# Build vocabulary file
# remove stopwords
# deleted 77 stop words
# split the dict
# percent_valid 2.5
# done
# len defs: 116566
# len batches 64142
# N train 32261
# rough max numbers: 32261 2107 82198
# total defs left to rpocess 79844
# ...

# %%
# !echo "floatX: float32" >> ~/.fuelrc

# %% [markdown]
# # Run

# %%
# !./run.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: True
# 	 epochs_done: 34
# 	 iterations_done: 92000
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 92000:
# 	 time_read_data_this_batch: 0.0206089496613
# 	 time_read_data_total: 1892.92101216
# 	 time_train_this_batch: 0.111984039545
# 	 time_train_total: 10363.2945492
# 	 train_length: 76.3850021362
# 	 train_mean_cost: 3.40085340187
# 	 train_seq2seq_apply_perplexity: 28.5675315857
# 	 train_seq2seq_apply_proximity_term: 0.011693617013
# 	 train_total_gradient_norm: 0.903612613678
#
#
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# ...

# %%
# !conda install pandas --yes -q
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mkl-service-2.3.0          |   py38he904b0f_0          68 KB
#     pytz-2020.1                |             py_0         239 KB
#     numpy-base-1.19.1          |   py38hfa32c7d_0         5.3 MB
#     mkl_random-1.1.1           |   py38h0573a6f_0         394 KB
#     certifi-2020.6.20          |           py38_0         160 KB
#     pandas-1.1.3               |   py38he6710b0_0        10.9 MB
#     pip-20.2.3                 |           py38_0         2.0 MB
#     openssl-1.1.1h             |       h7b6447c_0         3.8 MB
#     setuptools-50.3.0          |   py38hb0f4dca_1         902 KB
#     python-dateutil-2.8.1      |             py_0         224 KB
# ...

# %%
# !./evaluate_embeddings.sh
# Out:
# results/en_wn_full/s2sg_c300_pen8_c1_F
# s2sg_c300_pen8_c1_F in results/en_wn_full/s2sg_c300_pen8_c1_F/training_state.tar
# /usr/local/envs/cpae/lib/python2.7/site-packages/theano/gpuarray/dnn.py:184: UserWarning: Your cuDNN version is more recent than Theano. If you encounter problems, try updating Theano or downgrading cuDNN to a version >= v5 and <= v7.
#   warnings.warn("Your cuDNN version is more recent than "
# Using cuDNN version 7605 on context None
# Preallocating 7231/7611 Mb (0.950000) on cuda0
# Mapped name None to device cuda0: Tesla P4 (0000:00:04.0)
# Disabling SSL verification in HTTP
# generate embeddings
# {'batch_size': 32,
#  'batch_size_valid': 32,
#  'checkpoint_every_n_batches': 0,
#  'checkpoint_every_n_epochs': 0,
#  'data_path': '',
#  'decoder': 'skip-gram',
#  'dim': 300,
#  'emb_dim': 300,
#  'embedding_path': '',
#  'encoder': 'lstm',
#  'fast_checkpoint': True,
#  'freeze_pretrained': False,
#  'grad_clip_threshold': 5.0,
#  'layout': 'dict',
# ...
